# %% [markdown]
# # CSCV Research Demo
#
# Run the production pipeline from the repository root:
#
# ```bash
# python scripts/run_cscv_pipeline.py --contract ALL --n-splits 8
# ```
#
# Then inspect `results/report.md` and the CSV outputs under `results/tables/`.
